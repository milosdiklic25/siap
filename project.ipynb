# %% [markdown]
# U prvom data set-u nalaze se nominacije i dobitnici svih nagrada. Suzili smo samo na nagradu Best Picture (najbolji film)

# %%
import filter_best_picture

filter_best_picture.main()
# Out:
# === Best Picture Filter Script ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Input file:  C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\full_data.csv
# [INFO] Output file: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\best_picture_after_1970.csv
# [INFO] Loading dataset...
# [INFO] Loaded 12,014 rows, 16 columns.
# [INFO] Cleaning columns...
# [INFO] Year NA before: 0 | after coercion: 295 (newly coerced invalid years: 295)
# [INFO] Rows with CanonicalCategory == 'BEST PICTURE': 611
# [INFO] Applying filters: category='BEST PICTURE' AND year>=1970 ...
# [INFO] Filtered rows: 341
# [INFO] Filtered Year range: 1970–2024
# [INFO] Sample (first 5 rows):
#  Ceremony   Year Class CanonicalCategory     Category     NomId             Film    FilmId                                         Name                       Nominees          NomineeIds Winner Detail Note Citation MultifilmNomination
#        43 1970.0 Title      BEST PICTURE BEST PICTURE an0055872          Airport tt0065377                        Ross Hunter, Producer                    Ross Hunter           nm0403022    NaN    NaN  NaN      NaN                 NaN
#        43 1970.0 Title      BEST PICTURE BEST PICTURE an0055873 Five Easy Pieces tt0065724 Bob Rafelson and Richard Wechsler, Producers Bob Rafelson, Richard Wechsler nm0706182,nm0917061    NaN    NaN  NaN      NaN                 NaN
#        43 1970.0 Title      BEST PICTURE BEST PICTURE an0055874       Love Story tt0066011                   Howard G. Minsky, Producer               Howard G. Minsky           nm0591667    NaN    NaN  NaN      NaN                 NaN
#        43 1970.0 Title      BEST PICTURE BEST PICTURE an0055875          M*A*S*H tt0066026                     Ingo Preminger, Producer                 Ingo Preminger           nm0695931    NaN    NaN  NaN      NaN                 NaN
#        43 1970.0 Title      BEST PICTURE BEST PICTURE an0055871           Patton tt0066206                     Frank McCarthy, Producer                 Frank McCarthy           nm0565135   True    NaN  NaN      NaN                 NaN
# [INFO] Saving to best_picture_after_1970.csv ...
# [INFO] Saved successfully. File size: 66,785 bytes.
# [DONE] Filtering complete.

# %% [markdown]
# Stare filmove smo izbacili jer nema mnogo recenzija za njih.

# %%
import filter_old_movies

filter_old_movies.main()
# Out:
# === Movies After 1970 Filter ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Input:  C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies.csv
# [INFO] Output: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies_after_1970.csv
# [INFO] Year cutoff: 1970
# [INFO] Loading dataset...
# [INFO] Loaded 10,233 rows and 13 columns.
# [INFO] Columns: ['movieId', 'movieYear', 'movieURL', 'movieTitle', 'critic_score', 'critic_sentiment', 'audience_score', 'audience_sentiment', 'release_date_theaters', 'release_date_streaming', 'rating', 'original_language', 'runtime']
# [INFO] Converting 'movieYear' to numeric...
# [INFO] movieYear NA before: 0 | after coercion: 0 (newly coerced invalid years: 0)
# [INFO] movieYear range (overall): 1902–2024
# [INFO] Filtering movies with movieYear >= 1970 ...
# [INFO] Rows before: 10,233 | after: 9,777 | removed: 456
# [INFO] Preview of filtered data (first 5 rows):
# [INFO] Saving to movies_after_1970.csv ...
# [INFO] Saved successfully. File size: 2,077,901 bytes.
# [DONE] Filtering complete. New dataset saved as 'movies_after_1970.csv'.

# %% [markdown]
# Iz data set-a koji sadrzi sve filmove i podatke o njima (kao sto su critic score, audience score, audience sentiment, rating, language, runtime...) izbacili smo sve filmove koji nisu nominovani za Oskara.

# %%
import filter_best_picture_nominees

filter_best_picture_nominees.main()
# Out:
# === Best Picture Nominee Match Script ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Movies input file:       C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies_after_1970.csv
# [INFO] Best Picture input file: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\best_picture_after_1970.csv
# [INFO] Output file:            C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies_after_1970_best_picture_nominees.csv
# [INFO] Loading movies dataset...
# [INFO] Loaded movies: 9,777 rows, 13 columns.
# [INFO] Loading Best Picture dataset...
# [INFO] Loaded best_picture: 341 rows, 16 columns.
# [INFO] Extracting nominee names from best_picture['Film'] (strip/lower/unique)...
# [INFO] Total unique nominee names extracted: 341
# [INFO] Preview nominee names (first 10):
# ['airport' 'five easy pieces' 'love story' 'm*a*s*h' 'patton'
#  'a clockwork orange' 'fiddler on the roof' 'the french connection'
#  'the last picture show' 'nicholas and alexandra']
# [INFO] Normalizing movies['movieTitle'] for matching (strip/lower)...
# [INFO] Filtering movies by nominee titles...
# [INFO] Done. Kept 315 / 9,777 movies (3.22%).
# [INFO] Dropping helper column and saving output...
# [INFO] Saved successfully. File size: 68,982 bytes.
# [DONE] Saved as 'movies_after_1970_best_picture_nominees.csv'.

# %% [markdown]
# Imali smo 2 data set-a: jedan sa dobitnicima Oskara, drugi sa podacima o samim filmovima. Spojili smo ih tako da dobijemo data set sa svim filmovima koji su bili nominovani za Oskara, i da li su osvojili Oskara ili ne.

# %%
import expand_movie_with_winner_bool

expand_movie_with_winner_bool.main()
# Out:
# === Best Picture Winner Merge Script ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Best Picture input file: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\best_picture_after_1970.csv
# [INFO] Movies input file:       C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies_after_1970_best_picture_nominees.csv
# [INFO] Output file:            C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies_after_1970_best_picture_nominees_with_winner.csv
# [INFO] Loading datasets...
# [INFO] Loaded best_picture: 341 rows, 16 columns.
# [INFO] Loaded movies:       315 rows, 13 columns.
# [INFO] Cleaning title columns for matching (strip/lower)...
# [INFO] Converting best_picture['Winner'] to boolean 'winner'...
# [INFO] Winner==True count in best_picture: 55 (out of 341)
# [INFO] Preparing winner lookup table...
# [INFO] Winner lookup rows after drop_duplicates: 341
# [INFO] Merging movies with winner lookup...
# [INFO] Filling missing winner values with False...
# [INFO] Missing winner before fill: 0 | after fill: 0
# [INFO] Unmatched rows (no Film_clean found on merge): 0 / 315
# [INFO] Dropping helper columns...
# [INFO] Saving output to movies_after_1970_best_picture_nominees_with_winner.csv ...
# [INFO] Saved successfully. File size: 70,825 bytes.
# [DONE] Merge complete.

# %% [markdown]
# U filter_critic_reviews smo uklnoili sve recenzije koje se ne odnose na filmove iz prethodnog data set-a.

# %%
import filter_critic_reviews

filter_critic_reviews.main()
# Out:
# === Critic Reviews Filter + Clean Script ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Movies input file:  C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies_after_1970_best_picture_nominees.csv
# [INFO] Reviews input file: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews.csv
# [INFO] Output file:       C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews_filtered_cleaned.csv
# [INFO] Loading datasets...
# c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\filter_critic_reviews.py:24: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews = pd.read_csv(reviews_path)
# [INFO] Loaded movies:  315 rows, 13 columns.
# [INFO] Loaded reviews: 967,564 rows, 16 columns.
# [INFO] Building allowed movieId set from movies dataset...
# [INFO] Allowed movieIds: 315
# [INFO] Filtering reviews to allowed movieIds...
# [INFO] Original reviews: 967,564
# [INFO] Filtered reviews: 71,625
# [INFO] Removed reviews:  895,939
# [INFO] Dropping unnecessary columns (ignore if missing)...
# [INFO] Columns dropped: ['reviewId', 'criticName', 'criticPageUrl', 'publicationUrl', 'publicationName', 'reviewUrl', 'isRtUrl', 'creationDate']
# [INFO] Saving cleaned reviews to critic_reviews_filtered_cleaned.csv ...
# [INFO] Saved successfully. File size: 15,294,648 bytes.
# [INFO] Remaining columns: ['movieId', 'reviewState', 'isFresh', 'isRotten', 'isTopCritic', 'quote', 'scoreSentiment', 'originalScore']
# [DONE] Critic reviews filtering/cleaning complete.

# %% [markdown]
# U data set-u sa recenzijama nalaze se brojcane ocene filmova po razlicitim skalama (od 5, od 10, od -4, slovima...). Ocene su normalizovane tako da sve budu od 10.

# %%
import normalize_critic_scores

normalize_critic_scores.main()
# Out:
# === Critic Review Score Normalization Script ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Movies input file:  C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\movies_after_1970_best_picture_nominees.csv
# [INFO] Reviews input file: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews_filtered_cleaned.csv
# [INFO] Output file:       C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews_normalized.csv
# [INFO] Loading datasets...
# [INFO] Loaded movies:  315 rows, 13 columns.
# [INFO] Loaded reviews: 71,625 rows, 8 columns.
# [INFO] Building allowed movieId set from movies dataset...
# [INFO] Allowed movieIds: 315
# [INFO] Filtering reviews to allowed movieIds...
# [INFO] Reviews before filter: 71,625
# [INFO] Reviews after filter:  71,625
# [INFO] Removed reviews:       0
# [INFO] Normalizing 'originalScore' to a /10 scale...
# [INFO] originalScore NA: 22,950
# [INFO] normalized_score_10 NA (includes unknown formats): 23,409
# [INFO] Parsed scores: 48,216 / 71,625 (67.32%)
# [INFO] Saving normalized reviews to critic_reviews_normalized.csv ...
# [INFO] Saved successfully. File size: 15,529,093 bytes.
# [INFO] Normalization complete. Summary stats for normalized_score_10:
# count    48216.000000
# mean         8.222861
# std          1.587389
# min          0.000000
# 25%          7.500000
# 50%          8.500000
# 75%          9.500000
# max         18.000000
# Name: normalized_score_10, dtype: float64

# %% [markdown]
# Odradili smo brojne tehnike pretprocesiranja recenzija, kao sto su uklanjanje stop reci, stemming, prebacivanje u mala slova...

# %%
import preprocess_quotes

preprocess_quotes.main()
# Out:
# === Critic Review Text Preprocessing Script ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Input file:  C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews_normalized.csv
# [INFO] Output file: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews_normalized_textprocessed.csv
# [INFO] Ensuring NLTK stopwords are available...
# [INFO] Loaded stopwords: 198
# [INFO] Loading normalized reviews...
# [INFO] Loaded 71,625 rows, 9 columns.
# [INFO] Preprocessing 'quote' text...
# [INFO] quote NA: 1,571
# [INFO] quote_processed NA: 1,571
# [INFO] Saving output to critic_reviews_normalized_textprocessed.csv ...
# [INFO] Saved successfully. File size: 21,553,957 bytes.
# [DONE] Text preprocessing complete.
# [INFO] Columns now: ['movieId', 'reviewState', 'isFresh', 'isRotten', 'isTopCritic', 'quote', 'scoreSentiment', 'originalScore', 'normalized_score_10', 'quote_processed']
#
# [INFO] Example (first 3 rows):
#                                                                                                                                                     quote                                                                                  quote_processed
#                                                                                                                                                       NaN                                                                                              NaN
#      I always enjoy the movie when I watch it, but it will never hold anywhere near the same place in my heart or my memories as the long-running series.                  alway enjoy movi watch never hold anywher near place heart memori long run seri
# As a director Beatty has a light touch. He keeps the story moving briskly along. The movie never gets very serious and yet you care about the characters. director beatti light touch keep stori move briskli along movi never get seriou yet care charact

# %% [markdown]
# Koristili smo NLTK kako bismo kvantifikovali recenzije na skali izmedju -1 i 1 (dodela sentimenta komentaru).

# %%
import generate_quote_sentiment

generate_quote_sentiment.main()
# Out:
# === VADER Sentiment Analysis Script ===
# [INFO] Working directory: c:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3
# [INFO] Input file:  C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews_normalized_textprocessed.csv
# [INFO] Output file: C:\Users\milos.DESKTOP-K0ADGSS\Documents\Faks\siap3\critic_reviews_normalized_textprocessed_sentiment.csv
# [INFO] Ensuring NLTK VADER lexicon is available...
# [INFO] Loading input dataset...
# [INFO] Loaded 71,625 rows, 10 columns.
# [INFO] Initializing VADER SentimentIntensityAnalyzer...
# [INFO] Using column for sentiment analysis: quote_processed
# [INFO] Computing VADER sentiment (label + compound)...
# [INFO] NA in quote_processed: 1,574
# [INFO] NA in nltk_sentiment_compound: 1,574
# [INFO] Saving output to critic_reviews_normalized_textprocessed_sentiment.csv ...
# [INFO] Saved successfully. File size: 22,619,610 bytes.
# [DONE] Sentiment analysis complete.
# [INFO] Top sentiment label/compound combinations:
# nltk_sentiment_label  nltk_sentiment_compound
# neutral               0.0000                     15972
# positive              0.6369                      2510
#                       0.3612                      1725
#                       0.4404                      1668
#                       0.3182                      1334
#                       0.4588                      1147
#                       0.4215                      1113
#                       0.6249                      1058
#                       0.2732                      1055
#                       0.4019                       982
#
# [INFO] Compound score summary:
# count    70051.000000
# mean         0.218393
# std          0.435114
# min         -0.976900
# 25%          0.000000
# 50%          0.250000
# 75%          0.599400
# max          0.990800
# Name: nltk_sentiment_compound, dtype: float64

# %% [markdown]
# * Agregiramo recenzije na nivou filma
# * Spajamo ih sa podacima o nominacijama
# * Delimo train test podatke na osnovu zadate godine
# * SMOTE se koristi za balansiranje klasa
# * Trenira se Logistic Regression

# %%
import sys
import train_oscar_smote

sys.argv = [
    "train_oscar_smote.py",
    "--nominees_csv", "movies_after_1970_best_picture_nominees_with_winner.csv",
    "--reviews_csv", "critic_reviews_normalized_textprocessed_sentiment.csv",
    "--split_year", "2015",
    "--model", "logreg",
    "--smote_k", "3",
]

train_oscar_smote.main()
# Out:
# === Split ===
# Train years: <= 2015  (n=235)
# Test years : >  2015  (n=80)
# Train positives (winners): 46 / 235
# Test positives  (winners): 8 / 80
#
# === Confusion Matrix (threshold=0.5) ===
# [[41 31]
#  [ 5  3]]
#
# === Classification Report (threshold=0.5) ===
#               precision    recall  f1-score   support
#
#            0     0.8913    0.5694    0.6949        72
#            1     0.0882    0.3750    0.1429         8
#
#     accuracy                         0.5500        80
#    macro avg     0.4898    0.4722    0.4189        80
# weighted avg     0.8110    0.5500    0.6397        80
#
# ROC-AUC: 0.5417
#
# === Per-year top-pick accuracy ===
# Accuracy: 0.2222  (choose max proba nominee each year)
#
# === Top predicted nominee per year (test) ===
# 2016: La La Land | proba=0.775 | winner=False
# 2017: Three Billboards Outside Ebbing, Missouri | proba=0.993 | winner=False
# 2018: Vice | proba=0.948 | winner=False
# 2019: Parasite | proba=0.992 | winner=True
# 2020: Sound of Metal | proba=0.609 | winner=False
# 2021: Belfast | proba=0.925 | winner=False
# 2022: Avatar: The Way of Water | proba=0.939 | winner=False
# 2023: Oppenheimer | proba=0.825 | winner=True
# 2024: Dune: Part Two | proba=0.867 | winner=False
#
# Done.

# %% [markdown]
# Model je slab, tacnost je 55%, precision je vrlo nizak (8.8% - fake positives), 2/9 pogodjenih.

# %%
import sys
import train_oscar_smote

sys.argv = [
    "train_oscar_smote.py",
    "--nominees_csv", "movies_after_1970_best_picture_nominees_with_winner.csv",
    "--reviews_csv", "critic_reviews_normalized_textprocessed_sentiment.csv",
    "--split_year", "2015",
    "--model", "svm",
    "--smote_k", "3",
]

train_oscar_smote.main()
# Out:
# === Split ===
# Train years: <= 2015  (n=235)
# Test years : >  2015  (n=80)
# Train positives (winners): 46 / 235
# Test positives  (winners): 8 / 80
#
# === Confusion Matrix (threshold=0.5) ===
# [[26 46]
#  [ 2  6]]
#
# === Classification Report (threshold=0.5) ===
#               precision    recall  f1-score   support
#
#            0     0.9286    0.3611    0.5200        72
#            1     0.1154    0.7500    0.2000         8
#
#     accuracy                         0.4000        80
#    macro avg     0.5220    0.5556    0.3600        80
# weighted avg     0.8473    0.4000    0.4880        80
#
# ROC-AUC: 0.4809
#
# === Per-year top-pick accuracy ===
# Accuracy: 0.1111  (choose max proba nominee each year)
#
# === Top predicted nominee per year (test) ===
# 2016: La La Land | proba=0.884 | winner=False
# 2017: Three Billboards Outside Ebbing, Missouri | proba=0.997 | winner=False
# 2018: Bohemian Rhapsody | proba=0.889 | winner=False
# 2019: Joker | proba=0.982 | winner=False
# 2020: Sound of Metal | proba=0.902 | winner=False
# 2021: Dune | proba=0.924 | winner=False
# 2022: Tár | proba=0.966 | winner=False
# 2023: Oppenheimer | proba=0.905 | winner=True
# 2024: Dune: Part Two | proba=0.889 | winner=False
#
# Done.

# %% [markdown]
# Model ponovo slab, solidan recall (75%) ali los precision. 1/9 pogodjenih.
